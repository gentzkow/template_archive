# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('../output/data_merged.csv')

plt.hist(df['chips_sold']) #, bins=2, density=True)

plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y / len(df)*100:.0f}%'))
#plt.savefig('output/chips_sold.pdf')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
sns.kdeplot(df['percentage_column'])
plt.gca().xaxis.set_major_formatter(PercentFormatter(1))

# %%
80000 / len(df)
# Out:
# 0.25806451612903225

# %%
sns.kdeplot(df['chips_sold'], fill=True)

# Format y-axis as percentages
#plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y * 100:.1f}%'))

plt.xlabel('Chips Sold')
plt.ylabel('Percentage')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.hist(df['chips_sold'])

# Format y-axis as percentages of total count, but keep counts for y-axis scaling
total = len(df['chips_sold'])

plt.xlabel('Chips Sold')
plt.ylabel('Percentage')
plt.yscale('log')  # Optional: use log scale if counts vary greatly
plt.show()
